# %% [markdown]
# # import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # read csv data

# %%
auto_df=pd.read_csv('C:/Users/tech2k8/Documents/automobile data set.txt')
auto_df.head(10) #auto_df.tail(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %% [markdown]
# # write and save data

# %%
auto_df.to_excel('auto_df new.xlsx',sheet_name='auto',index='false')

# %% [markdown]
# # data types of the data set

# %%
auto_df.dtypes
#auto_df.shape
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# # Statistics of the data set

# %%
auto_df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %% [markdown]
# # index and slicing

# %%
#all columns view
auto_df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
#particular row view

#auto_df[2:5] 
#auto_df.loc[2:5]
auto_df.iloc[2:5]
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#   body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 2  hatchback          rwd           front        94.5  ...          152
# 3      sedan          fwd           front        99.8  ...          109
# 4      sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19    3.40              10.0        102      5500       24
# 4         mpfi  3.19    3.40               8.0        115      5500       18
#
#   highway-mpg  price
# 2          26  16500
# ...

# %%
#particular column view

auto_df['highway-mpg']
# Out:
# 0      27
# 1      27
# 2      26
# 3      30
# 4      22
#        ..
# 200    28
# 201    25
# 202    23
# 203    27
# 204    25
# Name: highway-mpg, Length: 205, dtype: int64

# %%
#type identification
type(auto_df['highway-mpg'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # descriptive statistics

# %%
print(auto_df['highway-mpg'].mean())
print(auto_df['highway-mpg'].max())
print(auto_df['highway-mpg'].min())
print(auto_df['highway-mpg'].median())
print(auto_df['highway-mpg'].mode())
print(auto_df['highway-mpg'].var())
print(auto_df['highway-mpg'].std())
# Out:
# 30.75121951219512
# 54
# 16
# 30.0
# 0    25
# dtype: int64
# 47.42309899569578
# 6.88644313094182

# %% [markdown]
# # set and reset index

# %%
auto_df.set_index('price')
# Out:
#        symboling normalized-losses         make fuel-type aspiration  \
# price
# 13495          3                 ?  alfa-romero       gas        std
# 16500          3                 ?  alfa-romero       gas        std
# 16500          1                 ?  alfa-romero       gas        std
# 13950          2               164         audi       gas        std
# 17450          2               164         audi       gas        std
# ...          ...               ...          ...       ...        ...
# 16845         -1                95        volvo       gas        std
# 19045         -1                95        volvo       gas      turbo
# 21485         -1                95        volvo       gas        std
# 22470         -1                95        volvo    diesel      turbo
# 22625         -1                95        volvo       gas      turbo
#
#       num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
auto_df.reset_index (inplace=True)

# %% [markdown]
# # column addition and deletion

# %%
auto_df['addition column']=pd.Series(np.arange(1,206))
auto_df.tail()
# Out:
#      index  symboling normalized-losses   make fuel-type aspiration  \
# 200    200         -1                95  volvo       gas        std
# 201    201         -1                95  volvo       gas      turbo
# 202    202         -1                95  volvo       gas        std
# 203    203         -1                95  volvo    diesel      turbo
# 204    204         -1                95  volvo       gas      turbo
#
#     num-of-doors body-style drive-wheels engine-location  ...  fuel-system  \
# 200         four      sedan          rwd           front  ...         mpfi
# 201         four      sedan          rwd           front  ...         mpfi
# 202         four      sedan          rwd           front  ...         mpfi
# 203         four      sedan          rwd           front  ...          idi
# 204         four      sedan          rwd           front  ...         mpfi
#
#      bore  stroke  compression-ratio  horsepower peak-rpm city-mpg  \
# ...

# %%
del auto_df['addition column']
#auto_df.pop('addition column')
auto_df.head()
# Out:
#    index  symboling normalized-losses         make fuel-type aspiration  \
# 0      0          3                 ?  alfa-romero       gas        std
# 1      1          3                 ?  alfa-romero       gas        std
# 2      2          1                 ?  alfa-romero       gas        std
# 3      3          2               164         audi       gas        std
# 4      4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  engine-size  \
# 0          two  convertible          rwd           front  ...          130
# 1          two  convertible          rwd           front  ...          130
# 2          two    hatchback          rwd           front  ...          152
# 3         four        sedan          fwd           front  ...          109
# 4         four        sedan          4wd           front  ...          136
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %% [markdown]
# # row addition and deletion

# %%
df=pd.DataFrame([1,2],columns=['aspiration'],index=['a','b'])
new_auto_df=auto_df.append(df)
new_auto_df
# Out:
#     aspiration   body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 0          std  convertible  3.47      21.0                9.0       2548.0
# 1          std  convertible  3.47      21.0                9.0       2548.0
# 2          std    hatchback  2.68      19.0                9.0       2823.0
# 3          std        sedan  3.19      24.0               10.0       2337.0
# 4          std        sedan  3.19      18.0                8.0       2824.0
# ..         ...          ...   ...       ...                ...          ...
# 202        std        sedan  3.58      18.0                8.8       3012.0
# 203      turbo        sedan  3.01      26.0               23.0       3217.0
# 204      turbo        sedan  3.78      19.0                9.5       3062.0
# a            1          NaN   NaN       NaN                NaN          NaN
# b            2          NaN   NaN       NaN                NaN          NaN
#
# ...

# %%
auto_df=new_auto_df.drop(['a','b'])
auto_df
# Out:
#     aspiration   body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 0          std  convertible  3.47      21.0                9.0       2548.0
# 1          std  convertible  3.47      21.0                9.0       2548.0
# 2          std    hatchback  2.68      19.0                9.0       2823.0
# 3          std        sedan  3.19      24.0               10.0       2337.0
# 4          std        sedan  3.19      18.0                8.0       2824.0
# ..         ...          ...   ...       ...                ...          ...
# 200        std        sedan  3.78      23.0                9.5       2952.0
# 201      turbo        sedan  3.78      19.0                8.7       3049.0
# 202        std        sedan  3.58      18.0                8.8       3012.0
# 203      turbo        sedan  3.01      26.0               23.0       3217.0
# 204      turbo        sedan  3.78      19.0                9.5       3062.0
#
# ...

# %% [markdown]
# # particular value access

# %%
auto_df[auto_df['price']>='16500']
# Out:
#     aspiration   body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 1          std  convertible  3.47      21.0                9.0       2548.0
# 2          std    hatchback  2.68      19.0                9.0       2823.0
# 4          std        sedan  3.19      18.0                8.0       2824.0
# 6          std        sedan  3.19      19.0                8.5       2844.0
# 7          std        wagon  3.19      19.0                8.5       2954.0
# ..         ...          ...   ...       ...                ...          ...
# 200        std        sedan  3.78      23.0                9.5       2952.0
# 201      turbo        sedan  3.78      19.0                8.7       3049.0
# 202        std        sedan  3.58      18.0                8.8       3012.0
# 203      turbo        sedan  3.01      26.0               23.0       3217.0
# 204      turbo        sedan  3.78      19.0                9.5       3062.0
#
# ...

# %%
auto_df[auto_df['price']==auto_df['price'].min()]
# Out:
#     aspiration body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 147        std      wagon  3.62      25.0                9.0       2455.0
#
#     drive-wheels engine-location  engine-size engine-type  ...    make  \
# 147          fwd           front        108.0        ohcf  ...  subaru
#
#     normalized-losses  num-of-cylinders  num-of-doors peak-rpm  price  stroke  \
# 147                89              four          four     5200  10198    2.64
#
#     symboling wheel-base width
# 147       0.0       97.0  65.4
#
# [1 rows x 27 columns]

# %%
auto_df[['make','price']][auto_df['price']==auto_df['price'].min()]
# Out:
#        make  price
# 147  subaru  10198

# %%
auto_df[['make']][auto_df['make']=='volvo']
# Out:
#       make
# 194  volvo
# 195  volvo
# 196  volvo
# 197  volvo
# 198  volvo
# 199  volvo
# 200  volvo
# 201  volvo
# 202  volvo
# 203  volvo
# 204  volvo
