# %%
#READ DATA

import pandas as pd
import numpy as np
auto_df=pd.read_excel('C:/Users/tech2k8/data clean nxt to data wrangling.xlsx','auto')
auto_df.head(5)
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3                122  alfa-romero       gas        std
# 1           1          3                122  alfa-romero       gas        std
# 2           2          1                122  alfa-romero       gas        std
# 3           3          2                164         audi       gas        std
# 4           4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  engine-size  \
# 0          two  convertible          rwd           front  ...          130
# 1          two  convertible          rwd           front  ...          130
# 2          two    hatchback          rwd           front  ...          152
# 3         four        sedan          fwd           front  ...          109
# 4         four        sedan          4wd           front  ...          136
#
# ...

# %%
#DATA WRANGLING

#GROUP BY

group=auto_df.groupby('make')
group

# %%
#ITERATING MAKE COLUMN 
#SPLIT TO COMBINE

for make,a in group:
    print(make)
    print(a)
# Out:
# alfa-romero
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3                122  alfa-romero       gas        std
# 1           1          3                122  alfa-romero       gas        std
# 2           2          1                122  alfa-romero       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  engine-size  \
# 0          two  convertible          rwd           front  ...          130
# 1          two  convertible          rwd           front  ...          130
# 2          two    hatchback          rwd           front  ...          152
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0         mpfi  3.47    2.68                9.0        111   5000.0        21
# 1         mpfi  3.47    2.68                9.0        111   5000.0        21
# 2         mpfi  2.68    3.47                9.0        154   5000.0        19
#
#   highway-mpg  price
# ...

# %%
#BMW CAR GROUP

group.get_group('bmw')
# Out:
#     Unnamed: 0  symboling  normalized-losses make fuel-type aspiration  \
# 10          10          2                192  bmw       gas        std
# 11          11          0                192  bmw       gas        std
# 12          12          0                188  bmw       gas        std
# 13          13          0                188  bmw       gas        std
# 14          14          1                122  bmw       gas        std
# 15          15          0                122  bmw       gas        std
# 16          16          0                122  bmw       gas        std
# 17          17          0                122  bmw       gas        std
#
#    num-of-doors body-style drive-wheels engine-location  ...  engine-size  \
# 10          two      sedan          rwd           front  ...          108
# 11         four      sedan          rwd           front  ...          108
# 12          two      sedan          rwd           front  ...          164
# ...

# %%
#DESCRIBE()

print(group.describe())
# Out:
#               Unnamed: 0                                                    \
#                    count      mean       std    min     25%    50%     75%
# make
# alfa-romero          3.0    1.0000  1.000000    0.0    0.50    1.0    1.50
# audi                 7.0    6.0000  2.160247    3.0    4.50    6.0    7.50
# bmw                  8.0   13.5000  2.449490   10.0   11.75   13.5   15.25
# chevrolet            3.0   19.0000  1.000000   18.0   18.50   19.0   19.50
# dodge                8.0   24.7500  2.815772   21.0   22.75   24.5   26.50
# honda               13.0   36.0000  3.894440   30.0   33.00   36.0   39.00
# isuzu                4.0   44.5000  1.290994   43.0   43.75   44.5   45.25
# jaguar               3.0   48.0000  1.000000   47.0   47.50   48.0   48.50
# mazda               16.0   57.6875  5.042734   50.0   53.75   57.5   61.25
# mercedes-benz        8.0   70.5000  2.449490   67.0   68.75   70.5   72.25
# ...

# %%
#PLOT

print(group.plot())
# Out:
# make
# alfa-romero      AxesSubplot(0.125,0.125;0.775x0.755)
# audi             AxesSubplot(0.125,0.125;0.775x0.755)
# bmw              AxesSubplot(0.125,0.125;0.775x0.755)
# chevrolet        AxesSubplot(0.125,0.125;0.775x0.755)
# dodge            AxesSubplot(0.125,0.125;0.775x0.755)
# honda            AxesSubplot(0.125,0.125;0.775x0.755)
# isuzu            AxesSubplot(0.125,0.125;0.775x0.755)
# jaguar           AxesSubplot(0.125,0.125;0.775x0.755)
# mazda            AxesSubplot(0.125,0.125;0.775x0.755)
# mercedes-benz    AxesSubplot(0.125,0.125;0.775x0.755)
# mercury          AxesSubplot(0.125,0.125;0.775x0.755)
# mitsubishi       AxesSubplot(0.125,0.125;0.775x0.755)
# nissan           AxesSubplot(0.125,0.125;0.775x0.755)
# peugot           AxesSubplot(0.125,0.125;0.775x0.755)
# plymouth         AxesSubplot(0.125,0.125;0.775x0.755)
# porsche          AxesSubplot(0.125,0.125;0.775x0.755)
# renault          AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %%
#aggregation

group.agg(['max','min','std','mean'])
# Out:
#               Unnamed: 0                          symboling                \
#                      max  min       std      mean       max min       std
# make
# alfa-romero            2    0  1.000000    1.0000         3   1  1.154701
# audi                   9    3  2.160247    6.0000         2   0  0.755929
# bmw                   17   10  2.449490   13.5000         2   0  0.744024
# chevrolet             20   18  1.000000   19.0000         2   0  1.000000
# dodge                 29   21  2.815772   24.7500         3  -1  1.069045
# honda                 42   30  3.894440   36.0000         2   0  0.767948
# isuzu                 46   43  1.290994   44.5000         2   0  0.957427
# jaguar                49   47  1.000000   48.0000         0   0  0.000000
# mazda                 66   50  5.042734   57.6875         3   0  1.167262
# mercedes-benz         74   67  2.449490   70.5000         3  -1  1.414214
# mercury               75   75       NaN   75.0000         1   1       NaN
# ...

# %% [markdown]
# # pivot and pivot table RESHAPE DATAFRAME

# %%
auto_df=pd.pivot_table(auto_df,index=['body-style','num-of-doors'], values='normalized-losses')
auto_df
# Out:
#                           normalized-losses
# body-style  num-of-doors
# convertible two                  127.333333
# hardtop     two                  128.625000
# hatchback   four                 100.000000
#             two                  135.750000
# sedan       four                 117.354430
#             two                  137.800000
# wagon       four                  98.560000
